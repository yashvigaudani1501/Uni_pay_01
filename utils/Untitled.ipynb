# %%
from werkzeug.security import generate_password_hash
print(generate_password_hash("Admin@123"))
# Out:
# scrypt:32768:8:1$lxpP6ZngAzTFtbRL$ea432013ad2b1130ff38d794f5c79060c6318bce693cf5a9748fbe808ce927154be5589b9ff8e41dbef3bd23a898adc8b4616c00df3fed96e2a22ec096b556f9
